# %%
# Load the dataset, display the ten first lines, store the results in a variable called 'client_0_bills'.
# What is the data type of the 'client_0_bills' variable ?
# Display the general information of the dataset and try to answer the following questions :
# How many rows and columns do we have in this dataset ?
# How many categorical features are present in the dataset ?
# How much memory space does the dataset consume ?
# Inspect the dataset for potential missing values.
# Select your strategy to handle missing values, and tell us why you had made that choice.
# Run a descriptive analysis on numeric features (columns).
# Select the bills records for the client with an id ='train_Client_0', using 2 methods.
# Transform the 'counter_type' feature to a numeric variable using the encoder of your choice.
# Delete the 'counter_statue' feature from the Dataframe

# %%
import pandas as pd

# %%
#1 Load the dataset, display the ten first lines, store the results in a variable called 'client_0_bills'
client_0_bills = pd.read_csv(r"STEG_BILLING_HISTORY.csv", low_memory=False)
client_0_bills
# Out:
#                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11       1335667.0
# 1            train_Client_0   2013-03-29          11       1335667.0
# 2            train_Client_0   2015-03-23          11       1335667.0
# 3            train_Client_0   2015-07-13          11       1335667.0
# 4            train_Client_0   2016-11-17          11       1335667.0
# ...                     ...          ...         ...             ...
# 167406  train_Client_104508   2014-05-28          11       1179651.0
# 167407  train_Client_104508   2014-01-31          11       1179651.0
# 167408  train_Client_104508   2009-09-29          11       1179651.0
# 167409  train_Client_104508   2010-01-02          11       1179651.0
# 167410  train_Client_104508   2012-01-27          11       1179651.0
#
#         counter_statue  counter_code  reading_remarque  counter_coefficient  \
# 0                    0           203               8.0                    1
# 1                    0           203               6.0                    1
# 2                    0           203               8.0                    1
# 3                    0           207               8.0                    1
# 4                    0           207               9.0                    1
# ...                ...           ...               ...                  ...
# 167406               0           203               6.0                    1
# 167407               0           203               9.0                    1
# 167408               0           203               6.0                    1
# 167409               0           203               6.0                    1
# 167410               0           203               6.0                    1
#
#         consommation_level_1  consommation_level_2  consommation_level_3  \
# 0                         82                     0                     0
# 1                       1200                   184                     0
# 2                        123                     0                     0
# 3                        102                     0                     0
# 4                        572                     0                     0
# ...                      ...                   ...                   ...
# 167406                   358                     0                     0
# 167407                   411                     0                     0
# 167408                   258                     0                     0
# 167409                   294                     0                     0
# 167410                   468                     0                     0
#
#         consommation_level_4  old_index  new_index  months_number counter_type
# 0                          0      14302    14384.0            4.0         ELEC
# 1                          0      12294    13678.0            4.0         ELEC
# 2                          0      14624    14747.0            4.0         ELEC
# 3                          0      14747    14849.0            4.0         ELEC
# 4                          0      15066    15638.0           12.0         ELEC
# ...                      ...        ...        ...            ...          ...
# 167406                     0       7056     7414.0            4.0         ELEC
# 167407                     0       6645     7056.0            4.0         ELEC
# 167408                     0       1926     2184.0            4.0         ELEC
# 167409                     0       2184     2478.0            4.0         ELEC
# 167410                     0       4281        NaN            NaN          NaN
#
# [167411 rows x 16 columns]

# %%
#1 Load the dataset, display the ten first lines, store the results in a variable called 'client_0_bills'
client_0_bills.head(10)
# Out:
#         client_id invoice_date  tarif_type  counter_number  counter_statue  \
# 0  train_Client_0   2014-03-24          11       1335667.0               0
# 1  train_Client_0   2013-03-29          11       1335667.0               0
# 2  train_Client_0   2015-03-23          11       1335667.0               0
# 3  train_Client_0   2015-07-13          11       1335667.0               0
# 4  train_Client_0   2016-11-17          11       1335667.0               0
# 5  train_Client_0   2017-07-17          11       1335667.0               0
# 6  train_Client_0   2018-12-07          11       1335667.0               0
# 7  train_Client_0   2019-03-19          11       1335667.0               0
# 8  train_Client_0   2011-07-22          11       1335667.0               0
# 9  train_Client_0   2011-11-22          11       1335667.0               0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# 0           203               8.0                    1                    82
# 1           203               6.0                    1                  1200
# 2           203               8.0                    1                   123
# 3           207               8.0                    1                   102
# 4           207               9.0                    1                   572
# 5           207               9.0                    1                   314
# 6           207               9.0                    1                   541
# 7           207               9.0                    1                   585
# 8           203               9.0                    1                  1200
# 9           203               6.0                    1                  1082
#
#    consommation_level_2  consommation_level_3  consommation_level_4  \
# 0                     0                     0                     0
# 1                   184                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
# 5                     0                     0                     0
# 6                     0                     0                     0
# 7                     0                     0                     0
# 8                   186                     0                     0
# 9                     0                     0                     0
#
#    old_index  new_index  months_number counter_type
# 0      14302    14384.0            4.0         ELEC
# 1      12294    13678.0            4.0         ELEC
# 2      14624    14747.0            4.0         ELEC
# 3      14747    14849.0            4.0         ELEC
# 4      15066    15638.0           12.0         ELEC
# 5      15638    15952.0            8.0         ELEC
# 6      15952    16493.0           12.0         ELEC
# 7      16493    17078.0            8.0         ELEC
# 8       7770     9156.0            4.0         ELEC
# 9       9156    10238.0            4.0         ELEC

# %%
 #2 What is the data type of the 'client_0_bills' variable ?
print(type(client_0_bills))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#3. Display the general information of the dataset and try to answer the following questions :
client_0_bills.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167411 entries, 0 to 167410
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   client_id             167411 non-null  object
#  1   invoice_date          167411 non-null  object
#  2   tarif_type            167411 non-null  int64
#  3   counter_number        167409 non-null  float64
#  4   counter_statue        167411 non-null  int64
#  5   counter_code          167411 non-null  int64
#  6   reading_remarque      167232 non-null  float64
#  7   counter_coefficient   167411 non-null  int64
#  8   consommation_level_1  167411 non-null  int64
#  9   consommation_level_2  167411 non-null  int64
#  10  consommation_level_3  167411 non-null  int64
#  11  consommation_level_4  167411 non-null  int64
#  12  old_index             167411 non-null  int64
#  13  new_index             167410 non-null  float64
#  14  months_number         167410 non-null  float64
#  15  counter_type          167410 non-null  object
# dtypes: float64(4), int64(9), object(3)
# memory usage: 20.4+ MB

# %%
#3A  How many rows and columns do we have in this dataset ?
Row_number, Column_number = client_0_bills.shape
print(" The number of rows and columns are" , Row_number, "and" ,Column_number, "respectively")
# Out:
#  The number of rows and columns are 167411 and 16 respectively

# %%
#3b  How many categorical features are present in the dataset ?
categorical = client_0_bills.select_dtypes('object').head(2)
display(categorical)
categorical1 = client_0_bills.select_dtypes(include = 'object').head(2)
display(categorical1)
# Out:
#         client_id invoice_date counter_type
# 0  train_Client_0   2014-03-24         ELEC
# 1  train_Client_0   2013-03-29         ELEC
#         client_id invoice_date counter_type
# 0  train_Client_0   2014-03-24         ELEC
# 1  train_Client_0   2013-03-29         ELEC

# %%
#3c How much memory space does the dataset consume
client_0_bills.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167411 entries, 0 to 167410
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   client_id             167411 non-null  object
#  1   invoice_date          167411 non-null  object
#  2   tarif_type            167411 non-null  int64
#  3   counter_number        167409 non-null  float64
#  4   counter_statue        167411 non-null  int64
#  5   counter_code          167411 non-null  int64
#  6   reading_remarque      167232 non-null  float64
#  7   counter_coefficient   167411 non-null  int64
#  8   consommation_level_1  167411 non-null  int64
#  9   consommation_level_2  167411 non-null  int64
#  10  consommation_level_3  167411 non-null  int64
#  11  consommation_level_4  167411 non-null  int64
#  12  old_index             167411 non-null  int64
#  13  new_index             167410 non-null  float64
#  14  months_number         167410 non-null  float64
#  15  counter_type          167410 non-null  object
# dtypes: float64(4), int64(9), object(3)
# memory usage: 49.1 MB

# %%
#3c How much memory space does the dataset consume
memory_usage = client_0_bills.memory_usage(deep=True).sum()
memory_usage
# Out:
# 51491177

# %%
#4Inspect the dataset for potential missing values
print(client_0_bills.isna().sum())
missing_counts = client_0_bills.isna().sum() / len(client_0_bills) * 100
print('\n')
print('\n')
print('\n')
print(missing_counts)
# Out:
# client_id                 0
# invoice_date              0
# tarif_type                0
# counter_number            2
# counter_statue            0
# counter_code              0
# reading_remarque        179
# counter_coefficient       0
# consommation_level_1      0
# consommation_level_2      0
# consommation_level_3      0
# consommation_level_4      0
# old_index                 0
# new_index                 1
# months_number             1
# counter_type              1
# dtype: int64
#
#
#
#
#
#
# client_id               0.000000
# invoice_date            0.000000
# tarif_type              0.000000
# counter_number          0.001195
# counter_statue          0.000000
# counter_code            0.000000
# reading_remarque        0.106922
# counter_coefficient     0.000000
# consommation_level_1    0.000000
# consommation_level_2    0.000000
# consommation_level_3    0.000000
# consommation_level_4    0.000000
# old_index               0.000000
# new_index               0.000597
# months_number           0.000597
# counter_type            0.000597
# dtype: float64

# %%
# 6Run a descriptive analysis on numeric features (columns).
client_0_bills.describe()
# Out:
#           tarif_type  counter_number  counter_statue   counter_code  \
# count  167411.000000    1.674090e+05   167411.000000  167411.000000
# mean       20.155850    9.617107e+10        0.041168     172.021229
# std        13.485314    1.420960e+12        0.369708     133.523150
# min         9.000000    0.000000e+00        0.000000       5.000000
# 25%        11.000000    1.214340e+05        0.000000       5.000000
# 50%        11.000000    5.047050e+05        0.000000     203.000000
# 75%        40.000000    1.124315e+06        0.000000     207.000000
# max        45.000000    2.738110e+13        5.000000     532.000000
#
#        reading_remarque  counter_coefficient  consommation_level_1  \
# count     167232.000000        167411.000000         167411.000000
# mean           7.314988             1.000012            408.349690
# std            1.360113             0.004888            603.963736
# min            6.000000             1.000000              0.000000
# 25%            6.000000             1.000000             76.000000
# 50%            6.000000             1.000000            269.000000
# 75%            9.000000             1.000000            600.000000
# max            9.000000             3.000000          93385.000000
#
#        consommation_level_2  consommation_level_3  consommation_level_4  \
# count         167411.000000         167411.000000         167411.000000
# mean             106.025076             21.745017             42.402405
# std              794.646355            285.156727            615.372446
# min                0.000000              0.000000              0.000000
# 25%                0.000000              0.000000              0.000000
# 50%                0.000000              0.000000              0.000000
# 75%                0.000000              0.000000              0.000000
# max            99398.000000          45360.000000          87776.000000
#
#            old_index      new_index  months_number
# count  167411.000000  167410.000000  167410.000000
# mean    17253.269576   17823.605973      38.310412
# std     37904.735215   38345.537066    1305.491070
# min         0.000000       0.000000       1.000000
# 25%      1751.000000    2021.250000       4.000000
# 50%      7487.000000    8000.000000       4.000000
# 75%     21442.000000   22122.750000       4.000000
# max    867253.000000  877022.000000   99104.000000

# %%
# 7Select the bills records for the client with an id ='train_Client_0', using 2 methods.
client_0_bills[client_0_bills['client_id'] =='train_Client_0']
# method two
client_0_bills.loc[client_0_bills['client_id'] =='train_Client_0']
#Method three
selected_records = client_0_bills.query("client_id == 'train_Client_0'")
selected_records
# Out:
#          client_id invoice_date  tarif_type  counter_number  counter_statue  \
# 0   train_Client_0   2014-03-24          11       1335667.0               0
# 1   train_Client_0   2013-03-29          11       1335667.0               0
# 2   train_Client_0   2015-03-23          11       1335667.0               0
# 3   train_Client_0   2015-07-13          11       1335667.0               0
# 4   train_Client_0   2016-11-17          11       1335667.0               0
# 5   train_Client_0   2017-07-17          11       1335667.0               0
# 6   train_Client_0   2018-12-07          11       1335667.0               0
# 7   train_Client_0   2019-03-19          11       1335667.0               0
# 8   train_Client_0   2011-07-22          11       1335667.0               0
# 9   train_Client_0   2011-11-22          11       1335667.0               0
# 10  train_Client_0   2008-11-25          11       1335667.0               0
# 11  train_Client_0   2012-07-23          11       1335667.0               0
# 12  train_Client_0   2012-11-29          11       1335667.0               0
# 13  train_Client_0   2013-07-22          11       1335667.0               0
# 14  train_Client_0   2014-07-18          11       1335667.0               0
# 15  train_Client_0   2014-11-24          11       1335667.0               0
# 16  train_Client_0   2015-11-18          11       1335667.0               0
# 17  train_Client_0   2012-03-27          11       1335667.0               0
# 18  train_Client_0   2011-03-30          11       1335667.0               0
# 19  train_Client_0   2013-02-12          11       1335667.0               0
# 20  train_Client_0   2010-07-22          11       1335667.0               0
# 21  train_Client_0   2010-11-24          11       1335667.0               0
# 22  train_Client_0   2005-10-17          11       1335667.0               0
# 23  train_Client_0   2006-02-24          11       1335667.0               0
# 24  train_Client_0   2006-06-23          11       1335667.0               0
# 25  train_Client_0   2006-10-18          11       1335667.0               0
# 26  train_Client_0   2007-06-27          11       1335667.0               0
# 27  train_Client_0   2007-10-25          11       1335667.0               0
# 28  train_Client_0   2007-02-26          11       1335667.0               0
# 29  train_Client_0   2008-07-28          11       1335667.0               0
# 30  train_Client_0   2009-01-04          11       1335667.0               0
# 31  train_Client_0   2009-07-27          11       1335667.0               0
# 32  train_Client_0   2009-11-24          11       1335667.0               0
# 33  train_Client_0   2010-03-29          11       1335667.0               0
# 34  train_Client_0   2008-01-04          11       1335667.0               0
#
#     counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# 0            203               8.0                    1                    82
# 1            203               6.0                    1                  1200
# 2            203               8.0                    1                   123
# 3            207               8.0                    1                   102
# 4            207               9.0                    1                   572
# 5            207               9.0                    1                   314
# 6            207               9.0                    1                   541
# 7            207               9.0                    1                   585
# 8            203               9.0                    1                  1200
# 9            203               6.0                    1                  1082
# 10           203               6.0                    1                   174
# 11           203               6.0                    1                   628
# 12           203               6.0                    1                   886
# 13           203               8.0                    1                   147
# 14           203               8.0                    1                    99
# 15           203               8.0                    1                   141
# 16           207               9.0                    1                   217
# 17           203               8.0                    1                   292
# 18           203               6.0                    1                   497
# 19           203               8.0                    1                    38
# 20           203               6.0                    1                   278
# 21           203               6.0                    1                   234
# 22           203               6.0                    1                   124
# 23           203               6.0                    1                   141
# 24           203               6.0                    1                   162
# 25           203               6.0                    1                   159
# 26           203               6.0                    1                   240
# 27           203               6.0                    1                   276
# 28           203               6.0                    1                   182
# 29           203               6.0                    1                   171
# 30           203               6.0                    1                   315
# 31           203               6.0                    1                   312
# 32           203               6.0                    1                   267
# 33           203               6.0                    1                   276
# 34           203               6.0                    1                   277
#
#     consommation_level_2  consommation_level_3  consommation_level_4  \
# 0                      0                     0                     0
# 1                    184                     0                     0
# 2                      0                     0                     0
# 3                      0                     0                     0
# 4                      0                     0                     0
# 5                      0                     0                     0
# 6                      0                     0                     0
# 7                      0                     0                     0
# 8                    186                     0                     0
# 9                      0                     0                     0
# 10                     0                     0                     0
# 11                     0                     0                     0
# 12                     0                     0                     0
# 13                     0                     0                     0
# 14                     0                     0                     0
# 15                     0                     0                     0
# 16                     0                     0                     0
# 17                     0                     0                     0
# 18                     0                     0                     0
# 19                     0                     0                     0
# 20                     0                     0                     0
# 21                     0                     0                     0
# 22                     0                     0                     0
# 23                     0                     0                     0
# 24                     0                     0                     0
# 25                     0                     0                     0
# 26                     0                     0                     0
# 27                     0                     0                     0
# 28                     0                     0                     0
# 29                     0                     0                     0
# 30                     0                     0                     0
# 31                     0                     0                     0
# 32                     0                     0                     0
# 33                     0                     0                     0
# 34                     0                     0                     0
#
#     old_index  new_index  months_number counter_type
# 0       14302    14384.0            4.0         ELEC
# 1       12294    13678.0            4.0         ELEC
# 2       14624    14747.0            4.0         ELEC
# 3       14747    14849.0            4.0         ELEC
# 4       15066    15638.0           12.0         ELEC
# 5       15638    15952.0            8.0         ELEC
# 6       15952    16493.0           12.0         ELEC
# 7       16493    17078.0            8.0         ELEC
# 8        7770     9156.0            4.0         ELEC
# 9        9156    10238.0            4.0         ELEC
# 10       5417     5591.0            4.0         ELEC
# 11      10780    11408.0            4.0         ELEC
# 12      11408    12294.0            4.0         ELEC
# 13      13983    14130.0            4.0         ELEC
# 14      14384    14483.0            4.0         ELEC
# 15      14483    14624.0            4.0         ELEC
# 16      14849    15066.0            4.0         ELEC
# 17      10488    10780.0            4.0         ELEC
# 18       7273     7770.0            4.0         ELEC
# 19      14264    14302.0            2.0         ELEC
# 20       6761     7039.0            4.0         ELEC
# 21       7039     7273.0            4.0         ELEC
# 22       3685     3809.0            4.0         ELEC
# 23       3809     3950.0            4.0         ELEC
# 24       3950     4112.0            4.0         ELEC
# 25       4112     4271.0            4.0         ELEC
# 26       4453     4693.0            4.0         ELEC
# 27       4693     4969.0            4.0         ELEC
# 28       4271     4453.0            4.0         ELEC
# 29       5246     5417.0            4.0         ELEC
# 30       5591     5906.0            4.0         ELEC
# 31       5906     6218.0            4.0         ELEC
# 32       6218     6485.0            4.0         ELEC
# 33       6485     6761.0            4.0         ELEC
# 34       4969     5246.0            4.0         ELEC

# %%
#8Transform the 'counter_type' feature to a numeric variable using the encoder of your choice.
from sklearn.preprocessing import LabelEncoder
data = {'counter_type': ['ELEC']}
df = pd.DataFrame(data)
label_encoder = LabelEncoder()
df['counter_type_numeric'] = label_encoder.fit_transform(df['counter_type'])
print(df)
# Out:
#   counter_type  counter_type_numeric
# 0         ELEC                     0

# %%
#9 Delete the 'counter_statue' feature from the Dataframe
data= {'counter_statue': [0]}
df = pd.DataFrame(data)
df = df.drop('counter_statue', axis=1)
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]
